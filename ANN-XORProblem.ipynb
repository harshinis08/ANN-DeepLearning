# %% [markdown]
# # Import libraries

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %% [markdown]
# * Why XOR ? because it is non-linearly separable problem
# * XOR problem training samples

# %%
training_data = np.array([[0,0],[0,1],[1,0],[1,1]], 'float32')

# %%
target_data = np.array([[0],[1],[1],[0]], 'float32')

# %% [markdown]
# # Defining Neural Network layers in Sequential Manner

# %%
model = Sequential()

# %%
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(16, input_dim=16, activation='relu'))
model.add(Dense(16, input_dim=16, activation='relu'))
model.add(Dense(16, input_dim=16, activation='relu'))
model.add(Dense(16, input_dim=16, activation='relu'))
model.add(Dense(16, input_dim=16, activation='relu'))
model.add(Dense(16, input_dim=16, activation='relu'))

# %%
model.add(Dense(1, activation = 'sigmoid'))

# %% [markdown]
# * We can define the loss function MSE or negative log likelihood
# * optimizers will find the right adjustments for the weights: SGD, Adagrad, ADAM

# %%
model.compile(loss = 'mean_squared_error', 
             optimizer = 'adam',
             metrics = ['binary_accuracy'])

# %% [markdown]
# * Epoch is an iteration over the entire dataset
# * Verbose 0 is silent, 1 and 2 are showing results

# %%
model.fit(training_data, target_data, epochs=1000, verbose=2)
# Out:
# Epoch 1/1000
#  - 1s - loss: 0.2501 - binary_accuracy: 0.7500
# Epoch 2/1000
#  - 0s - loss: 0.2494 - binary_accuracy: 0.5000
# Epoch 3/1000
#  - 0s - loss: 0.2487 - binary_accuracy: 0.5000
# Epoch 4/1000
#  - 0s - loss: 0.2481 - binary_accuracy: 1.0000
# Epoch 5/1000
#  - 0s - loss: 0.2474 - binary_accuracy: 1.0000
# Epoch 6/1000
#  - 0s - loss: 0.2468 - binary_accuracy: 1.0000
# Epoch 7/1000
#  - 0s - loss: 0.2462 - binary_accuracy: 1.0000
# Epoch 8/1000
#  - 0s - loss: 0.2456 - binary_accuracy: 1.0000
# Epoch 9/1000
#  - 0s - loss: 0.2450 - binary_accuracy: 1.0000
# Epoch 10/1000
#  - 0s - loss: 0.2446 - binary_accuracy: 1.0000
# Epoch 11/1000
#  - 0s - loss: 0.2441 - binary_accuracy: 1.0000
# Epoch 12/1000
#  - 0s - loss: 0.2436 - binary_accuracy: 1.0000
# Epoch 13/1000
#  - 0s - loss: 0.2431 - binary_accuracy: 1.0000
# Epoch 14/1000
#  - 0s - loss: 0.2424 - binary_accuracy: 1.0000
# Epoch 15/1000
#  - 0s - loss: 0.2417 - binary_accuracy: 1.0000
# Epoch 16/1000
# ...

# %%
print(model.predict(training_data).round())
# Out:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
